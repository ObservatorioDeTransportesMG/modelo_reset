# %%
import pandas as pd

residencias = pd.read_csv("residencias.csv")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_24704\4167314124.py:3: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   residencias = pd.read_csv("residencias.csv")

# %%
residencias['longitude'] = residencias['longitude']/1000000
residencias['latitude'] = residencias['latitude']/1000000

# %%
# residencias.to_csv('residencias_tratado.csv')

# %%
residencias
# Out:
#             id  longitude   latitude    Z Measure  OID_  ORIG_FID           x  \
# 0            1 -43.808868 -16.702423  NaN     NaN   0.0         0 -4876780.91
# 1            2 -43.808859 -16.702366  NaN     NaN   0.0         1 -4876779.90
# 2            3 -43.808842 -16.702326  NaN     NaN   0.0         2 -4876777.97
# 3            4 -43.808818 -16.702288  NaN     NaN   0.0         3 -4876775.26
# 4            5 -43.808790 -16.702248  NaN     NaN   0.0         4 -4876772.21
# ...        ...        ...        ...  ...     ...   ...       ...         ...
# 131859  131860 -43.812104 -16.721937  NaN     NaN   0.0    131859 -4877141.10
# 131860  131861 -43.812122 -16.721797  NaN     NaN   0.0    131860 -4877143.06
# 131861  131862 -43.812141 -16.721654  NaN     NaN   0.0    131861 -4877145.22
# 131862  131863 -43.811820 -16.721723  NaN     NaN   0.0    131862 -4877109.51
# 131863  131864 -43.811888 -16.721485  NaN     NaN   0.0    131862 -4877109.51
#
#                  y  REGIAO  LINK_ID  NODE_ID  HAB/EDIF 2022  \
# 0      -1873939.00       5     5698     4366       1.028188
# 1      -1873932.49       5     5698     4366       1.028188
# 2      -1873927.80       5     5696     4366       1.028188
# 3      -1873923.43       5     5696     4366       1.028188
# 4      -1873918.81       5     5696     4366       1.028188
# ...            ...     ...      ...      ...            ...
# 131859 -1876193.19       3     6239     3323       1.186420
# 131860 -1876177.02       3     6239     3323       1.186420
# 131861 -1876160.51       3     6239     3323       1.186420
# 131862 -1876168.42       3     6237     3322       1.186420
# 131863 -1876168.42       3     6237     4724       1.186420
#
#         DEMANDA_RECICLAGEM  Container 10
# 0                 0.195356          4518
# 1                 0.195356          4518
# 2                 0.195356          4518
# 3                 0.195356          4518
# 4                 0.195356          4518
# ...                    ...           ...
# 131859            0.225420          5833
# 131860            0.225420          5833
# 131861            0.225420          5833
# 131862            0.225420          5833
# 131863            0.225420          5833
#
# [131864 rows x 15 columns]
